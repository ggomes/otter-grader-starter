# %% [raw]
# # ASSIGNMENT CONFIG
# name: nameofthelab
# files:
#     - resources
# generate:
#   show_hidden: true
#   show_all_public: true
# solutions_pdf: false
# template_pdf: false
# check_all_cell: true
# export_cell:
#     pdf: false
#     instructions: "Make sure you submit the .zip file to Gradescope."
#     run_tests: false

# %% [markdown]
# ---
#
# <h3><center>COURSE TITLE</center></h3>
#
# <h2><center>Lab session #XXX <br></center></h2>
#
# <h1><center>TITLE OF THE LAB<br></center></h1>
#
# ---

# %%
from resources.hashutils import *
import numpy as np

# %% [markdown]
# # Question 1: TITLE OF THE QUESTION
#
# Description
#
# <img src="resources/myimage.png" />

# %% [raw]
# # BEGIN QUESTION
# name: q1p1

# %% [markdown]
# ## Question 1.1: TITLE OF THE SUBQUESTION
#
# DESCRIPTION

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
alpha = 0.1
def myfunction(T):
    return -alpha*(T-2)
# END SOLUTION
""" # BEGIN PROMPT
alpha = ...
def myfunction(T):
    return ...
""" # END PROMPT
# Out:
# ' # BEGIN PROMPT\nalpha = ...\ndef myfunction(T):\n    return ...\n'

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
""" # BEGIN TEST CONFIG
hidden: false
points: 0
""" # END TEST CONFIG
alpha>0 and alpha<1
# Out:
# True

# %%
""" # BEGIN TEST CONFIG
hidden: false
points: 1
""" # END TEST CONFIG
get_hash(alpha,4)=='cb5ae17636e975f9bf71ddf5bc542075'
# Out:
# 'cb5ae17636e975f9bf71ddf5bc542075'

# %%
""" # BEGIN TEST CONFIG
hidden: false
points: 1
""" # END TEST CONFIG
get_hash(myfunction(np.array([0,100,-100])),4)=='fd033c3db20132b6bf7f1fcf04a525b6'
# Out:
# 'fd033c3db20132b6bf7f1fcf04a525b6'

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION
